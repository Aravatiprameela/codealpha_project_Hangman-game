# %%
# Tuple
# Tiple indexing
tuple_a=(1,2,3,"a","b","c")
tuple_a[4]
# Out:
# 'b'

# %%
# Tuple Slicing
tuple_a=(1,2,3,"a","b","c")
tuple_a[3:6]
# Out:
# ('a', 'b', 'c')

# %%
tuple_a=(1,2,3,"a","b","c")
tuple_a[:2:-1]
# Out:
# ('c', 'b', 'a')

# %%
# list on tuple
list_tuple=[10,9,8,7,(1,2,3,"a","b","c"),11,12]
print(list_tuple)
# Out:
# [10, 9, 8, 7, (1, 2, 3, 'a', 'b', 'c'), 11, 12]

# %%
# Tuple on list
list_tuple=(10,9,8,7,[1,2,3,"a","b","c"],11,12)
print(list_tuple)
# Out:
# (10, 9, 8, 7, [1, 2, 3, 'a', 'b', 'c'], 11, 12)
